# %%
import pandas as pd
from network_detection.network_predictor import NetworkThreatPredictor

# %%
df = pd.read_csv(
    r"datasets/raw/cicids2017_cleaned.csv",
    nrows=5
)

# %%
sample = df.drop(columns=["Attack Type"])

# %%
predictor = NetworkThreatPredictor()

results = predictor.predict(sample)

print(results)
# Out:
# [{'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 99.91, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}]

# %%
print(results)
# Out:
# [{'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 99.91, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}, {'prediction': 'Normal Traffic', 'confidence': 100.0, 'risk_level': 'Safe', 'description': 'Normal network traffic detected.', 'recommendation': 'No action required.'}]
